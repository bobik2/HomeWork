# %%
#2
Path_A = input
Path_b = input
X = np.array(list(map(float, input().split())))
#X = split(string,' ')
df_A = read_csv(Path_A, sep ='s+', dtype = np.float64, header = None) 
b = read_csv(Path_b, sep ='s+', dtype = np.float64, header = None) 
A2 = df_A ** 2
X.T @ A2 @ b

# %%
#3 
import pandas as pd
rates = pd.read_csv('C:/Users/57662/Downloads/rates001.csv',sep = ';')
games = pd.read_csv('C:/Users/57662/Downloads/games001.csv',sep = ';')
top = rates.groupby('id').mean().sort_values('mark',ascending= False).head(3)
top
# Out:
#         mark
# id
# 3   9.000000
# 1   8.866667
# 2   8.333333

# %%
merged = pd.merge(top, games[:3], how='inner', on = 'id')
merged.iloc[:, [1, 2]]
# Out:
#        mark             name
# 0  9.000000  Darkest Dungeon
# 1  8.866667           XCOM 2
# 2  8.333333   Civilization V

# %%
rates_sorted = rates[rates.mark >= 8].groupby('id').aggregate({'mark':'count'}).rename(columns = {'mark':'number'})
rates_sorted
# Out:
#     number
# id
# 1       14
# 2        9
# 3        4
# 4        3

# %%
games
# Out:
#    id             name           company
# 0   1           XCOM 2           Firaxis
# 1   2   Civilization V           Firaxis
# 2   3  Darkest Dungeon  Red Hook Studios
# 3   4     Star Traders    Trese Brothers

# %%
df = pd.merge(rates_sorted, games, how='inner', on = 'id')
df
# Out:
#    id  number             name           company
# 0   1      14           XCOM 2           Firaxis
# 1   2       9   Civilization V           Firaxis
# 2   3       4  Darkest Dungeon  Red Hook Studios
# 3   4       3     Star Traders    Trese Brothers

# %%
df.groupby('company').aggregate({'name':'count'}).sort_values('name',ascending= False).head(1)
# Out:
#          name
# company
# Firaxis     2

# %%
#4
papers = pd.read_csv('C:/Users/57662/Downloads/papers001.csv',sep=';')
links = pd.read_csv('C:/Users/57662/Downloads/links001.csv',sep=';')
papers
# Out:
#    id        title    author
# 0   1    Title One    Ivanov
# 1   2    Title Two   Sidorov
# 2   3  Title Three    Petrov
# 3   4   Title Four  A.N.Onim
# 4   5   Title Five    Petrov
# 5   6    Title Six    Petrov
# 6   7  Title Seven   Sidorov

# %%
links
# Out:
#    paper_id       reference
# 0         1       Title Two
# 1         1     Title Three
# 2         1  Something Else
# 3         1        Offtopic
# 4         2     Title Three
# 5         2      Title Four
# 6         2  One More Paper
# 7         3             Foo
# 8         4             Bar

# %%
new_links = links.groupby('reference').aggregate({'paper_id':'count'}).rename(columns ={'reference':'title'})
new_links
# Out:
#                 paper_id
# reference
# Bar                    1
# Foo                    1
# Offtopic               1
# One More Paper         1
# Something Else         1
# Title Four             1
# Title Three            2
# Title Two              1

# %%
df2 = pd.merge(papers, new_links, how='inner', on = 'title')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15468/37023683.py in <module>
# ----> 1 df2 = pd.merge(papers, new_links, how='inner', on = 'title')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
#1
N, M = map(int,(input().split()))
ocean_df = pd.DataFrame([np.array(((input().split()))) for i in range(N)])
first = (ocean_df < -5).values.sum()
second = 1/(ocean_df[ocean_df < 0].fillna(0).values.sum())
third = ocean_df.values.max()
print(first,second,third)
